# %% [markdown]
# ### Importing all required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Creating dataframe for data

# %%
df=pd.read_csv("cardekho_dataset.csv",index_col=0)

# %%
df
# Out:
#               car_name     brand     model  vehicle_age  km_driven  \
# 0          Maruti Alto    Maruti      Alto            9     120000
# 1        Hyundai Grand   Hyundai     Grand            5      20000
# 2          Hyundai i20   Hyundai       i20           11      60000
# 3          Maruti Alto    Maruti      Alto            9      37000
# 4        Ford Ecosport      Ford  Ecosport            6      30000
# ...                ...       ...       ...          ...        ...
# 19537      Hyundai i10   Hyundai       i10            9      10723
# 19540    Maruti Ertiga    Maruti    Ertiga            2      18000
# 19541      Skoda Rapid     Skoda     Rapid            6      67000
# 19542  Mahindra XUV500  Mahindra    XUV500            5    3800000
# 19543       Honda City     Honda      City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0      Individual    Petrol            Manual    19.70     796      46.30
# ...

# %% [markdown]
# ### Undestanding the data

# %%
df.shape
# Out:
# (15411, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15411 entries, 0 to 19543
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car_name           15411 non-null  object
#  1   brand              15411 non-null  object
#  2   model              15411 non-null  object
#  3   vehicle_age        15411 non-null  int64
#  4   km_driven          15411 non-null  int64
#  5   seller_type        15411 non-null  object
#  6   fuel_type          15411 non-null  object
#  7   transmission_type  15411 non-null  object
#  8   mileage            15411 non-null  float64
#  9   engine             15411 non-null  int64
#  10  max_power          15411 non-null  float64
#  11  seats              15411 non-null  int64
#  12  selling_price      15411 non-null  int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 1.6+ MB

# %%
## checking if there are any null values
df.isnull().sum()
# Out:
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
df.dtypes
# Out:
# car_name              object
# brand                 object
# model                 object
# vehicle_age            int64
# km_driven              int64
# seller_type           object
# fuel_type             object
# transmission_type     object
# mileage              float64
# engine                 int64
# max_power            float64
# seats                  int64
# selling_price          int64
# dtype: object

# %%
df["fuel_type"].dtype
# Out:
# dtype('O')

# %%
df.columns
# Out:
# Index(['car_name', 'brand', 'model', 'vehicle_age', 'km_driven', 'seller_type',
#        'fuel_type', 'transmission_type', 'mileage', 'engine', 'max_power',
#        'seats', 'selling_price'],
#       dtype='object')

# %%
for feature in df.columns:
    if df[feature].dtype == 'O':
        print("Feature: ",feature)
        print(df[feature].unique(),end=" ")
        print(df[feature].value_counts())
        print(f"\n{"*"*100}\n")
# Out:
# Feature:  car_name
# ['Maruti Alto' 'Hyundai Grand' 'Hyundai i20' 'Ford Ecosport'
#  'Maruti Wagon R' 'Hyundai i10' 'Hyundai Venue' 'Maruti Swift'
#  'Hyundai Verna' 'Renault Duster' 'Mini Cooper' 'Maruti Ciaz'
#  'Mercedes-Benz C-Class' 'Toyota Innova' 'Maruti Baleno'
#  'Maruti Swift Dzire' 'Volkswagen Vento' 'Hyundai Creta' 'Honda City'
#  'Mahindra Bolero' 'Toyota Fortuner' 'Renault KWID' 'Honda Amaze'
#  'Hyundai Santro' 'Mahindra XUV500' 'Mahindra KUV100' 'Maruti Ignis'
#  'Datsun RediGO' 'Mahindra Scorpio' 'Mahindra Marazzo' 'Ford Aspire'
#  'Ford Figo' 'Maruti Vitara' 'Tata Tiago' 'Volkswagen Polo' 'Kia Seltos'
#  'Maruti Celerio' 'Datsun GO' 'BMW 5' 'Honda CR-V' 'Ford Endeavour'
#  'Mahindra KUV' 'Honda Jazz' 'BMW 3' 'Audi A4' 'Tata Tigor'
#  'Maruti Ertiga' 'Tata Safari' 'Mahindra Thar' 'Tata Hexa'
#  'Land Rover Rover' 'Maruti Eeco' 'Audi A6' 'Mercedes-Benz E-Class'
#  'Audi Q7' 'BMW Z4' 'BMW 6' 'Jaguar XF' 'BMW X5' 'MG Hector' 'Honda Civic'
# ...

# %%
df.columns
# Out:
# Index(['car_name', 'brand', 'model', 'vehicle_age', 'km_driven', 'seller_type',
#        'fuel_type', 'transmission_type', 'mileage', 'engine', 'max_power',
#        'seats', 'selling_price'],
#       dtype='object')

# %%
df.head()
# Out:
#         car_name    brand     model  vehicle_age  km_driven seller_type  \
# 0    Maruti Alto   Maruti      Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai     Grand            5      20000  Individual
# 2    Hyundai i20  Hyundai       i20           11      60000  Individual
# 3    Maruti Alto   Maruti      Alto            9      37000  Individual
# 4  Ford Ecosport     Ford  Ecosport            6      30000      Dealer
#
#   fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0    Petrol            Manual    19.70     796      46.30      5
# 1    Petrol            Manual    18.90    1197      82.00      5
# 2    Petrol            Manual    17.00    1197      80.00      5
# 3    Petrol            Manual    20.92     998      67.10      5
# 4    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000

# %%
new_df=df[~df['brand'].isin(["Mercedes-Benz", "Skoda", "Audi", "Datsun", "Jaguar", "Land Rover", "Jeep", "Kia", "Porsche", "Volvo", "MG", "Mini", "Nissan", "Lexus", "Isuzu", "Bentley", "Maserati", "ISUZU", "Ferrari", "Mercedes-AMG", "Rolls-Royce", "Force"])]
new_df=new_df[new_df['fuel_type'].isin(['Petrol','Diesel'])]

# %%
new_df
# Out:
# Empty DataFrame
# Columns: [car_name, brand, model, vehicle_age, km_driven, seller_type, fuel_type, transmission_type, mileage, engine, max_power, seats, selling_price]
# Index: []

# %%
new_df.shape
# Out:
# (0, 13)

# %%
for feature in df.columns:
    if df[feature].dtype == 'O':
        print("Feature: ",feature)
        print(df[feature].unique(),end=" ")
        print(df[feature].value_counts())
        print(f"\n{"*"*100}\n")
# Out:
# Feature:  car_name
# ['Maruti Alto' 'Hyundai Grand' 'Hyundai i20' 'Ford Ecosport'
#  'Maruti Wagon R' 'Hyundai i10' 'Hyundai Venue' 'Maruti Swift'
#  'Hyundai Verna' 'Renault Duster' 'Mini Cooper' 'Maruti Ciaz'
#  'Mercedes-Benz C-Class' 'Toyota Innova' 'Maruti Baleno'
#  'Maruti Swift Dzire' 'Volkswagen Vento' 'Hyundai Creta' 'Honda City'
#  'Mahindra Bolero' 'Toyota Fortuner' 'Renault KWID' 'Honda Amaze'
#  'Hyundai Santro' 'Mahindra XUV500' 'Mahindra KUV100' 'Maruti Ignis'
#  'Datsun RediGO' 'Mahindra Scorpio' 'Mahindra Marazzo' 'Ford Aspire'
#  'Ford Figo' 'Maruti Vitara' 'Tata Tiago' 'Volkswagen Polo' 'Kia Seltos'
#  'Maruti Celerio' 'Datsun GO' 'BMW 5' 'Honda CR-V' 'Ford Endeavour'
#  'Mahindra KUV' 'Honda Jazz' 'BMW 3' 'Audi A4' 'Tata Tigor'
#  'Maruti Ertiga' 'Tata Safari' 'Mahindra Thar' 'Tata Hexa'
#  'Land Rover Rover' 'Maruti Eeco' 'Audi A6' 'Mercedes-Benz E-Class'
#  'Audi Q7' 'BMW Z4' 'BMW 6' 'Jaguar XF' 'BMW X5' 'MG Hector' 'Honda Civic'
# ...

# %%
df['brand'].value_counts()
# Out:
# brand
# Maruti           4992
# Hyundai          2982
# Honda            1485
# Mahindra         1011
# Toyota            793
# Ford              790
# Volkswagen        620
# Renault           536
# BMW               439
# Tata              430
# Mercedes-Benz     337
# Skoda             334
# Audi              192
# Datsun            170
# Jaguar             59
# Land Rover         51
# Jeep               41
# Kia                32
# Porsche            21
# Volvo              20
# MG                 19
# Mini               17
# Nissan             11
# Lexus              10
# Isuzu               8
# Bentley             3
# Maserati            2
# ISUZU               2
# Ferrari             1
# Mercedes-AMG        1
# Rolls-Royce         1
# Force               1
# Name: count, dtype: int64

# %%
new_df=df[~df['brand'].isin(["Mercedes-Benz", "Skoda", "Audi", "Datsun", "Jaguar", "Land Rover", "Jeep", "Kia", "Porsche", "Volvo", "MG", "Mini", "Nissan", "Lexus", "Isuzu", "Bentley", "Maserati", "ISUZU", "Ferrari", "Mercedes-AMG", "Rolls-Royce", "Force"])]

# %%
new_df
# Out:
#               car_name     brand     model  vehicle_age  km_driven  \
# 0          Maruti Alto    Maruti      Alto            9     120000
# 1        Hyundai Grand   Hyundai     Grand            5      20000
# 2          Hyundai i20   Hyundai       i20           11      60000
# 3          Maruti Alto    Maruti      Alto            9      37000
# 4        Ford Ecosport      Ford  Ecosport            6      30000
# ...                ...       ...       ...          ...        ...
# 19536    Hyundai Grand   Hyundai     Grand            5       9229
# 19537      Hyundai i10   Hyundai       i10            9      10723
# 19540    Maruti Ertiga    Maruti    Ertiga            2      18000
# 19542  Mahindra XUV500  Mahindra    XUV500            5    3800000
# 19543       Honda City     Honda      City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0      Individual    Petrol            Manual    19.70     796      46.30
# ...

# %%
new_df
# Out:
#               car_name     brand     model  vehicle_age  km_driven  \
# 0          Maruti Alto    Maruti      Alto            9     120000
# 1        Hyundai Grand   Hyundai     Grand            5      20000
# 2          Hyundai i20   Hyundai       i20           11      60000
# 3          Maruti Alto    Maruti      Alto            9      37000
# 4        Ford Ecosport      Ford  Ecosport            6      30000
# ...                ...       ...       ...          ...        ...
# 19536    Hyundai Grand   Hyundai     Grand            5       9229
# 19537      Hyundai i10   Hyundai       i10            9      10723
# 19540    Maruti Ertiga    Maruti    Ertiga            2      18000
# 19542  Mahindra XUV500  Mahindra    XUV500            5    3800000
# 19543       Honda City     Honda      City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0      Individual    Petrol            Manual    19.70     796      46.30
# ...

# %%
useless_df=df[df['brand'].isin(["Mercedes-Benz", "Skoda", "Audi", "Datsun", "Jaguar", "Land Rover", "Jeep", "Kia", "Porsche", "Volvo", "MG", "Mini", "Nissan", "Lexus", "Isuzu", "Bentley", "Maserati", "ISUZU", "Ferrari", "Mercedes-AMG", "Rolls-Royce", "Force"])]
new_df=new_df[new_df['fuel_type'].isin(['Petrol','Diesel'])]

# %%
## Getting all categories of features which are of "object" data type
for feature in new_df.columns:
    if new_df[feature].dtype == 'O':
        print("Feature: ",feature)
        print(new_df[feature].unique(),end=" ")
        print(new_df[feature].value_counts())
        print(f"\n{"*"*100}\n")
# Out:
# Feature:  car_name
# ['Maruti Alto' 'Hyundai Grand' 'Hyundai i20' 'Ford Ecosport'
#  'Maruti Wagon R' 'Hyundai i10' 'Hyundai Venue' 'Maruti Swift'
#  'Hyundai Verna' 'Renault Duster' 'Maruti Ciaz' 'Toyota Innova'
#  'Maruti Baleno' 'Maruti Swift Dzire' 'Volkswagen Vento' 'Hyundai Creta'
#  'Honda City' 'Mahindra Bolero' 'Toyota Fortuner' 'Renault KWID'
#  'Honda Amaze' 'Hyundai Santro' 'Mahindra XUV500' 'Mahindra KUV100'
#  'Maruti Ignis' 'Mahindra Scorpio' 'Mahindra Marazzo' 'Ford Aspire'
#  'Ford Figo' 'Maruti Vitara' 'Tata Tiago' 'Volkswagen Polo'
#  'Maruti Celerio' 'BMW 5' 'Honda CR-V' 'Ford Endeavour' 'Mahindra KUV'
#  'Honda Jazz' 'BMW 3' 'Tata Tigor' 'Maruti Ertiga' 'Tata Safari'
#  'Mahindra Thar' 'Tata Hexa' 'Maruti Eeco' 'BMW Z4' 'BMW 6' 'BMW X5'
#  'Honda Civic' 'BMW X1' 'Ford Freestyle' 'Tata Nexon' 'Mahindra XUV300'
#  'Maruti Dzire VXI' 'Honda WR-V' 'Maruti XL6' 'Renault Triber'
#  'Toyota Camry' 'Hyundai Elantra' 'Toyota Yaris' 'BMW 7' 'Maruti S-Presso'
# ...

# %%
new_df
# Out:
#               car_name     brand     model  vehicle_age  km_driven  \
# 0          Maruti Alto    Maruti      Alto            9     120000
# 1        Hyundai Grand   Hyundai     Grand            5      20000
# 2          Hyundai i20   Hyundai       i20           11      60000
# 3          Maruti Alto    Maruti      Alto            9      37000
# 4        Ford Ecosport      Ford  Ecosport            6      30000
# ...                ...       ...       ...          ...        ...
# 19536    Hyundai Grand   Hyundai     Grand            5       9229
# 19537      Hyundai i10   Hyundai       i10            9      10723
# 19540    Maruti Ertiga    Maruti    Ertiga            2      18000
# 19542  Mahindra XUV500  Mahindra    XUV500            5    3800000
# 19543       Honda City     Honda      City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0      Individual    Petrol            Manual    19.70     796      46.30
# ...

# %%
new_df=new_df[new_df['fuel_type'].isin(['Petrol','Diesel'])]

# %%
new_df.shape
# Out:
# (13729, 13)

# %%
new_df
# Out:
#               car_name     brand     model  vehicle_age  km_driven  \
# 0          Maruti Alto    Maruti      Alto            9     120000
# 1        Hyundai Grand   Hyundai     Grand            5      20000
# 2          Hyundai i20   Hyundai       i20           11      60000
# 3          Maruti Alto    Maruti      Alto            9      37000
# 4        Ford Ecosport      Ford  Ecosport            6      30000
# ...                ...       ...       ...          ...        ...
# 19536    Hyundai Grand   Hyundai     Grand            5       9229
# 19537      Hyundai i10   Hyundai       i10            9      10723
# 19540    Maruti Ertiga    Maruti    Ertiga            2      18000
# 19542  Mahindra XUV500  Mahindra    XUV500            5    3800000
# 19543       Honda City     Honda      City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 0      Individual    Petrol            Manual    19.70     796      46.30
# ...

# %%
model_counts=new_df['model'].value_counts()

# %%
model_counts=new_df['model'].value_counts()
valid_model_names=model_counts[model_counts>50]
print(len(valid_model_names))
new_df=new_df[new_df['model'].isin(valid_model_names)]
# Out:
# 43

# %%
valid_model_names
# Out:
# model
# i20            906
# Swift Dzire    883
# Swift          781
# City           756
# Alto           741
# Grand          576
# Wagon R        563
# Innova         543
# Verna          492
# i10            405
# Ecosport       374
# Polo           373
# Baleno         364
# Amaze          361
# Ciaz           346
# Creta          336
# XUV500         330
# KWID           306
# Vitara         295
# Ertiga         290
# Scorpio        273
# Figo           271
# Vento          247
# Celerio        218
# Duster         218
# Bolero         211
# Fortuner       187
# Jazz           175
# 3              152
# Tiago          145
# Santro         123
# 5              118
# WR-V           101
# Safari         100
# Nexon           85
# Eeco            80
# Ignis           73
# KUV             65
# Aspire          65
# Thar            62
# Civic           59
# Venue           58
# X1              54
# Name: count, dtype: int64

# %%
len(valid_model_names)
# Out:
# 43

# %%
new_df.shape
# Out:
# (0, 13)

# %%
new_df=new_df[new_df['model'].isin(valid_model_names)]

# %%
new_df.shape
# Out:
# (0, 13)

# %%
cars_count=new_df['car_name'].value_counts()

# %%
valid_car_names=cars_count[cars_count>20]

# %%
valid_car_names
# Out:
# Series([], Name: count, dtype: int64)

# %%
new_df=new_df[new_df['car_name'].isin(valid_car_names)]

# %%
new_df
# Out:
# Empty DataFrame
# Columns: [car_name, brand, model, vehicle_age, km_driven, seller_type, fuel_type, transmission_type, mileage, engine, max_power, seats, selling_price]
# Index: []

# %%
new_df=new_df.replace("Trustmark Dealer","Dealer")

# %%
new_df['seller_type'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
new_df
# Out:
# Empty DataFrame
# Columns: [car_name, brand, model, vehicle_age, km_driven, seller_type, fuel_type, transmission_type, mileage, engine, max_power, seats, selling_price]
# Index: []

# %%
new_df['car_name'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
new_df['transmission_type'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
for feature in
# Out:
#   Cell In[85], line 1
#     for feature in
#                    ^
# SyntaxError: invalid syntax
